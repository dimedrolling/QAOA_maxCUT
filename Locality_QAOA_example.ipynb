# %%
import numpy as np
import math
import itertools
import random
import matplotlib as mpl
import matplotlib.pyplot as plt
import qiskit
import qiskit.quantum_info as qi 
# import warnings
# warnings.filterwarnings('ignore')
import time
import networkx as nx
from QAOA_locality import *

# %% [markdown]
# # CHECK

# %%
ans = generate_QAOA_operator(nqubits=3,locality=2,number_of_terms=1,number_of_layers=1)
ans, max_loc, avg_loc, len_ans = count_solutions_XI(ans,1e-10)
ans
# Out:
# [('[0, 1, 0]', (0.49485474799704543+0j)),
#  ('[0, 0, 1]', (0.4948547479970455+0j))]

# %% [markdown]
# # PLOT GRID

# %%
# %load_ext line_profiler

# %%
# %lprun -f make_grid make_grid(5,3,3)

# %%
# %lprun -f count_solutions_XI count_solutions_XI(ans)

# %%
grid = make_grid(4, 4, 4,2)

# %%
plt.rcParams["figure.figsize"] = (40,10)

# %%
plot_grid(grid,mode=1)
